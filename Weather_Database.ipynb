# %%
# Create a new set of 2,000 random latitudes and longitudes.
# Get the nearest city using the citipy module.
# Perform an API call with the OpenWeatherMap.
# Retrieve the following information from the API call:
# Latitude and longitude - Maximum temperature - Percent humidity - Percent cloudiness - Wind speed - Weather description
# Add the data to a new DataFrame.
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
from citipy import citipy
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 727

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | poykovskiy
# Processing Record 3 of Set 1 | kirakira
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | kristinehamn
# Processing Record 6 of Set 1 | asosa
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | port macquarie
# Processing Record 15 of Set 1 | sinnamary
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | talah
# City not found. Skipping...
# Processing Record 19 of Set 1 | llallagua
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | saskylakh
# Processing Record 26 of Set 1 | solnechnyy
# Processing Record 27 of Set 1 | waingapu
# Processing Record 28 of Set 1 | tual
# Processing Record 29 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 30 of Set 1 | umm ruwabah
# City not found. Skipping...
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | leh
# Processing Record 33 of Set 1 | umm lajj
# Processing Record 34 of Set 1 | katsuura
# Processing Record 35 of Set 1 | inirida
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | champerico
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | terney
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | acapulco
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | lotoshino
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | port hawkesbury
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | garissa
# Processing Record 3 of Set 2 | bonthe
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | angra dos reis
# Processing Record 6 of Set 2 | saravan
# Processing Record 7 of Set 2 | mala
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | ahipara
# Processing Record 13 of Set 2 | isangel
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | shawville
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | guanay
# Processing Record 22 of Set 2 | playa vicente
# Processing Record 23 of Set 2 | nampula
# Processing Record 24 of Set 2 | bredasdorp
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | saint-leu
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | evensk
# Processing Record 31 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 32 of Set 2 | bocas del toro
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | margate
# Processing Record 35 of Set 2 | busselton
# Processing Record 36 of Set 2 | comodoro rivadavia
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | bambous virieux
# Processing Record 39 of Set 2 | manhattan
# Processing Record 40 of Set 2 | general roca
# Processing Record 41 of Set 2 | vestmannaeyjar
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | asbe teferi
# Processing Record 45 of Set 2 | tarakan
# Processing Record 46 of Set 2 | disna
# Processing Record 47 of Set 2 | kenai
# Processing Record 48 of Set 2 | tasiilaq
# Processing Record 49 of Set 2 | telimele
# Processing Record 50 of Set 2 | nalut
# Processing Record 1 of Set 3 | yulara
# Processing Record 2 of Set 3 | lebu
# Processing Record 3 of Set 3 | bowen
# Processing Record 4 of Set 3 | moranbah
# Processing Record 5 of Set 3 | saint george
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | gafanha da encarnacao
# Processing Record 8 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | iskateley
# Processing Record 12 of Set 3 | cherskiy
# Processing Record 13 of Set 3 | atyuryevo
# City not found. Skipping...
# Processing Record 14 of Set 3 | lodeynoye pole
# Processing Record 15 of Set 3 | awbari
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | waipawa
# Processing Record 18 of Set 3 | caravelas
# Processing Record 19 of Set 3 | faya
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | stubbekobing
# Processing Record 22 of Set 3 | grand gaube
# Processing Record 23 of Set 3 | kang
# Processing Record 24 of Set 3 | lumeje
# Processing Record 25 of Set 3 | nemuro
# Processing Record 26 of Set 3 | vostok
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | doka
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | priamurskiy
# Processing Record 33 of Set 3 | pueblo nuevo
# Processing Record 34 of Set 3 | khatanga
# Processing Record 35 of Set 3 | eyl
# Processing Record 36 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 3 | kensington
# Processing Record 38 of Set 3 | perth
# Processing Record 39 of Set 3 | brae
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | khorixas
# Processing Record 42 of Set 3 | horta
# Processing Record 43 of Set 3 | dalian
# Processing Record 44 of Set 3 | mount isa
# Processing Record 45 of Set 3 | srednekolymsk
# Processing Record 46 of Set 3 | banfora
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | luanda
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | ribeira grande
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | bac lieu
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | najran
# Processing Record 6 of Set 4 | varnavino
# Processing Record 7 of Set 4 | arcachon
# Processing Record 8 of Set 4 | mogadishu
# Processing Record 9 of Set 4 | port-gentil
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | puerto escondido
# Processing Record 12 of Set 4 | kokopo
# Processing Record 13 of Set 4 | tautira
# Processing Record 14 of Set 4 | rocha
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | antofagasta
# Processing Record 18 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | victoria
# Processing Record 21 of Set 4 | yauya
# Processing Record 22 of Set 4 | riyadh
# Processing Record 23 of Set 4 | fayetteville
# Processing Record 24 of Set 4 | korla
# Processing Record 25 of Set 4 | manokwari
# Processing Record 26 of Set 4 | codrington
# Processing Record 27 of Set 4 | okhotsk
# Processing Record 28 of Set 4 | samarai
# Processing Record 29 of Set 4 | roma
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | souillac
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | yar-sale
# Processing Record 34 of Set 4 | cartagena
# Processing Record 35 of Set 4 | port said
# Processing Record 36 of Set 4 | konin
# Processing Record 37 of Set 4 | sisimiut
# Processing Record 38 of Set 4 | price
# Processing Record 39 of Set 4 | buchanan
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | panzhihua
# Processing Record 42 of Set 4 | port hueneme
# Processing Record 43 of Set 4 | trelew
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | lahar
# Processing Record 46 of Set 4 | satana
# Processing Record 47 of Set 4 | ringe
# Processing Record 48 of Set 4 | arlit
# Processing Record 49 of Set 4 | samana
# Processing Record 50 of Set 4 | karoi
# Processing Record 1 of Set 5 | qaqortoq
# Processing Record 2 of Set 5 | camopi
# Processing Record 3 of Set 5 | sao felix do xingu
# Processing Record 4 of Set 5 | pochutla
# Processing Record 5 of Set 5 | teguldet
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | arkhangelsk
# Processing Record 8 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 5 | mbaiki
# Processing Record 10 of Set 5 | dalianwan
# Processing Record 11 of Set 5 | nadadores
# Processing Record 12 of Set 5 | porto novo
# Processing Record 13 of Set 5 | mgandu
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | saint-pierre
# Processing Record 16 of Set 5 | gejiu
# Processing Record 17 of Set 5 | ponta delgada
# Processing Record 18 of Set 5 | zhanaozen
# Processing Record 19 of Set 5 | chuy
# Processing Record 20 of Set 5 | cayenne
# Processing Record 21 of Set 5 | kapaa
# Processing Record 22 of Set 5 | sarankhola
# Processing Record 23 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 5 | santa clara
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | port keats
# Processing Record 27 of Set 5 | matamoros
# Processing Record 28 of Set 5 | palembang
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | urucara
# Processing Record 31 of Set 5 | deputatskiy
# Processing Record 32 of Set 5 | san cristobal
# Processing Record 33 of Set 5 | komsomolskiy
# Processing Record 34 of Set 5 | nanyuki
# Processing Record 35 of Set 5 | north bend
# Processing Record 36 of Set 5 | east london
# Processing Record 37 of Set 5 | kautokeino
# Processing Record 38 of Set 5 | mecca
# Processing Record 39 of Set 5 | saint anthony
# Processing Record 40 of Set 5 | puerto ayacucho
# Processing Record 41 of Set 5 | radenci
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | teya
# Processing Record 44 of Set 5 | lepe
# Processing Record 45 of Set 5 | sayyan
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | kristiansund
# Processing Record 50 of Set 5 | melita
# Processing Record 1 of Set 6 | ahuimanu
# Processing Record 2 of Set 6 | nanortalik
# Processing Record 3 of Set 6 | biltine
# Processing Record 4 of Set 6 | lesnoy
# Processing Record 5 of Set 6 | port lincoln
# Processing Record 6 of Set 6 | harper
# Processing Record 7 of Set 6 | shache
# Processing Record 8 of Set 6 | ucluelet
# Processing Record 9 of Set 6 | broome
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | chegdomyn
# Processing Record 12 of Set 6 | karaton
# Processing Record 13 of Set 6 | baker city
# Processing Record 14 of Set 6 | yuryevets
# Processing Record 15 of Set 6 | salym
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | tefe
# Processing Record 18 of Set 6 | chiredzi
# Processing Record 19 of Set 6 | maldonado
# Processing Record 20 of Set 6 | svetlogorsk
# Processing Record 21 of Set 6 | tromso
# Processing Record 22 of Set 6 | jacareacanga
# Processing Record 23 of Set 6 | seoul
# Processing Record 24 of Set 6 | sao domingos
# Processing Record 25 of Set 6 | aksu
# Processing Record 26 of Set 6 | okha
# Processing Record 27 of Set 6 | lotofaga
# Processing Record 28 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 6 | yangjiang
# Processing Record 30 of Set 6 | bar harbor
# Processing Record 31 of Set 6 | carson city
# Processing Record 32 of Set 6 | kerema
# Processing Record 33 of Set 6 | nikolskoye
# Processing Record 34 of Set 6 | san francisco
# Processing Record 35 of Set 6 | kaeo
# Processing Record 36 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 6 | ust-omchug
# Processing Record 38 of Set 6 | nurota
# Processing Record 39 of Set 6 | nemencine
# Processing Record 40 of Set 6 | juegang
# Processing Record 41 of Set 6 | auki
# Processing Record 42 of Set 6 | hervey bay
# Processing Record 43 of Set 6 | portland
# Processing Record 44 of Set 6 | kobryn
# Processing Record 45 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 6 | san quintin
# Processing Record 47 of Set 6 | valparaiso
# Processing Record 48 of Set 6 | buala
# Processing Record 49 of Set 6 | touros
# Processing Record 50 of Set 6 | guajara-mirim
# City not found. Skipping...
# Processing Record 1 of Set 7 | northam
# Processing Record 2 of Set 7 | kasongo-lunda
# Processing Record 3 of Set 7 | biak
# Processing Record 4 of Set 7 | kurilsk
# Processing Record 5 of Set 7 | colorines
# Processing Record 6 of Set 7 | xingcheng
# Processing Record 7 of Set 7 | jalu
# Processing Record 8 of Set 7 | roald
# Processing Record 9 of Set 7 | starobaltachevo
# Processing Record 10 of Set 7 | monte patria
# Processing Record 11 of Set 7 | zabol
# Processing Record 12 of Set 7 | diapaga
# Processing Record 13 of Set 7 | grindavik
# Processing Record 14 of Set 7 | mugur-aksy
# Processing Record 15 of Set 7 | klaksvik
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | marau
# Processing Record 18 of Set 7 | cantagallo
# Processing Record 19 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 7 | meulaboh
# Processing Record 21 of Set 7 | usak
# Processing Record 22 of Set 7 | novyy nekouz
# Processing Record 23 of Set 7 | arman
# Processing Record 24 of Set 7 | mount gambier
# Processing Record 25 of Set 7 | udachnyy
# Processing Record 26 of Set 7 | tiksi
# Processing Record 27 of Set 7 | murud
# Processing Record 28 of Set 7 | kutum
# Processing Record 29 of Set 7 | berezovyy
# Processing Record 30 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 7 | gilgit
# Processing Record 32 of Set 7 | huron
# Processing Record 33 of Set 7 | hopelchen
# Processing Record 34 of Set 7 | half moon bay
# Processing Record 35 of Set 7 | faanui
# Processing Record 36 of Set 7 | maragogi
# Processing Record 37 of Set 7 | guiyang
# Processing Record 38 of Set 7 | olinda
# Processing Record 39 of Set 7 | santiago de cuba
# Processing Record 40 of Set 7 | port blair
# Processing Record 41 of Set 7 | silifke
# Processing Record 42 of Set 7 | goiatuba
# Processing Record 43 of Set 7 | terrace bay
# Processing Record 44 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 7 | huaidian
# Processing Record 46 of Set 7 | russell
# Processing Record 47 of Set 7 | nivala
# Processing Record 48 of Set 7 | sao joao da barra
# Processing Record 49 of Set 7 | sarahan
# Processing Record 50 of Set 7 | pietarsaari
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | lompoc
# Processing Record 3 of Set 8 | homer
# Processing Record 4 of Set 8 | te anau
# Processing Record 5 of Set 8 | belgaum
# Processing Record 6 of Set 8 | yingshang
# City not found. Skipping...
# Processing Record 7 of Set 8 | stokmarknes
# Processing Record 8 of Set 8 | lakhipur
# Processing Record 9 of Set 8 | tifton
# Processing Record 10 of Set 8 | vila velha
# Processing Record 11 of Set 8 | fairbanks
# Processing Record 12 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 13 of Set 8 | san angelo
# Processing Record 14 of Set 8 | maceio
# Processing Record 15 of Set 8 | lukovetskiy
# Processing Record 16 of Set 8 | ferrol
# Processing Record 17 of Set 8 | guerrero negro
# Processing Record 18 of Set 8 | sucua
# Processing Record 19 of Set 8 | santa isabel do rio negro
# Processing Record 20 of Set 8 | tecpan
# Processing Record 21 of Set 8 | griffith
# Processing Record 22 of Set 8 | pangkalanbuun
# Processing Record 23 of Set 8 | tunxi
# City not found. Skipping...
# Processing Record 24 of Set 8 | cheney
# Processing Record 25 of Set 8 | port shepstone
# Processing Record 26 of Set 8 | koumac
# Processing Record 27 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 8 | vanimo
# Processing Record 29 of Set 8 | luena
# Processing Record 30 of Set 8 | lata
# Processing Record 31 of Set 8 | bedesa
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 8 | toora-khem
# Processing Record 35 of Set 8 | namatanai
# Processing Record 36 of Set 8 | ca mau
# Processing Record 37 of Set 8 | barreirinha
# Processing Record 38 of Set 8 | thinadhoo
# Processing Record 39 of Set 8 | baturaja
# Processing Record 40 of Set 8 | mishkino
# Processing Record 41 of Set 8 | hattiesburg
# Processing Record 42 of Set 8 | raudeberg
# Processing Record 43 of Set 8 | hay river
# Processing Record 44 of Set 8 | lorengau
# Processing Record 45 of Set 8 | santa maria
# Processing Record 46 of Set 8 | santa cruz
# Processing Record 47 of Set 8 | comarapa
# Processing Record 48 of Set 8 | sehithwa
# Processing Record 49 of Set 8 | mizdah
# Processing Record 50 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 9 | quesnel
# Processing Record 2 of Set 9 | chapleau
# Processing Record 3 of Set 9 | fort wellington
# Processing Record 4 of Set 9 | saa
# Processing Record 5 of Set 9 | brookhaven
# Processing Record 6 of Set 9 | fortuna
# Processing Record 7 of Set 9 | san juan de los morros
# Processing Record 8 of Set 9 | quatre cocos
# Processing Record 9 of Set 9 | whitehorse
# Processing Record 10 of Set 9 | torbay
# Processing Record 11 of Set 9 | tucuma
# Processing Record 12 of Set 9 | nome
# Processing Record 13 of Set 9 | yishui
# Processing Record 14 of Set 9 | rio do sul
# Processing Record 15 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 9 | dese
# Processing Record 17 of Set 9 | ossora
# Processing Record 18 of Set 9 | tigzirt
# Processing Record 19 of Set 9 | borisoglebskiy
# Processing Record 20 of Set 9 | bihoro
# Processing Record 21 of Set 9 | hambantota
# Processing Record 22 of Set 9 | bambanglipuro
# Processing Record 23 of Set 9 | zhovkva
# Processing Record 24 of Set 9 | camapua
# Processing Record 25 of Set 9 | olafsvik
# Processing Record 26 of Set 9 | beitbridge
# Processing Record 27 of Set 9 | kasongo
# Processing Record 28 of Set 9 | eureka
# Processing Record 29 of Set 9 | key west
# Processing Record 30 of Set 9 | tezu
# Processing Record 31 of Set 9 | ishigaki
# Processing Record 32 of Set 9 | san vito al tagliamento
# Processing Record 33 of Set 9 | brownwood
# Processing Record 34 of Set 9 | zaysan
# Processing Record 35 of Set 9 | marigot
# Processing Record 36 of Set 9 | hamilton
# Processing Record 37 of Set 9 | kachikau
# City not found. Skipping...
# Processing Record 38 of Set 9 | komsomolets
# Processing Record 39 of Set 9 | itigi
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | cortez
# Processing Record 42 of Set 9 | bengkulu
# Processing Record 43 of Set 9 | ylivieska
# Processing Record 44 of Set 9 | kralendijk
# Processing Record 45 of Set 9 | volsk
# Processing Record 46 of Set 9 | kargasok
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | mercedes
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 10 | kedrovyy
# Processing Record 2 of Set 10 | fasa
# Processing Record 3 of Set 10 | kysyl-syr
# Processing Record 4 of Set 10 | naze
# Processing Record 5 of Set 10 | mehamn
# Processing Record 6 of Set 10 | paamiut
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | kaitangata
# Processing Record 10 of Set 10 | san mateo del mar
# Processing Record 11 of Set 10 | kudahuvadhoo
# Processing Record 12 of Set 10 | necochea
# Processing Record 13 of Set 10 | macarthur
# Processing Record 14 of Set 10 | champasak
# Processing Record 15 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 16 of Set 10 | gamba
# Processing Record 17 of Set 10 | yablonovo
# Processing Record 18 of Set 10 | dunedin
# Processing Record 19 of Set 10 | chicama
# Processing Record 20 of Set 10 | san patricio
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | ixtapa
# Processing Record 23 of Set 10 | outjo
# Processing Record 24 of Set 10 | ponezhukay
# Processing Record 25 of Set 10 | bongandanga
# Processing Record 26 of Set 10 | ternate
# Processing Record 27 of Set 10 | marienburg
# Processing Record 28 of Set 10 | port-cartier
# Processing Record 29 of Set 10 | saint-augustin
# Processing Record 30 of Set 10 | camocim
# Processing Record 31 of Set 10 | skjervoy
# Processing Record 32 of Set 10 | pareora
# Processing Record 33 of Set 10 | madridejos
# Processing Record 34 of Set 10 | naples
# Processing Record 35 of Set 10 | ahome
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | redmond
# Processing Record 38 of Set 10 | bilma
# Processing Record 39 of Set 10 | shakawe
# Processing Record 40 of Set 10 | babu
# Processing Record 41 of Set 10 | boguchany
# Processing Record 42 of Set 10 | tazmalt
# Processing Record 43 of Set 10 | basqal
# Processing Record 44 of Set 10 | irklievskaya
# City not found. Skipping...
# Processing Record 45 of Set 10 | gorontalo
# Processing Record 46 of Set 10 | olden
# Processing Record 47 of Set 10 | santa rosa
# Processing Record 48 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 10 | vao
# Processing Record 50 of Set 10 | barcelona
# Processing Record 1 of Set 11 | buraydah
# Processing Record 2 of Set 11 | abeche
# Processing Record 3 of Set 11 | inuvik
# Processing Record 4 of Set 11 | ginda
# Processing Record 5 of Set 11 | palmer
# Processing Record 6 of Set 11 | karratha
# Processing Record 7 of Set 11 | krasnoselkup
# Processing Record 8 of Set 11 | holalkere
# Processing Record 9 of Set 11 | acari
# Processing Record 10 of Set 11 | cleveland
# Processing Record 11 of Set 11 | sopelana
# Processing Record 12 of Set 11 | alyangula
# Processing Record 13 of Set 11 | virginia beach
# Processing Record 14 of Set 11 | kimberley
# Processing Record 15 of Set 11 | kembe
# Processing Record 16 of Set 11 | fereydun kenar
# Processing Record 17 of Set 11 | winchester
# Processing Record 18 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 11 | santo antonio do ica
# Processing Record 21 of Set 11 | mathathane
# Processing Record 22 of Set 11 | morondava
# Processing Record 23 of Set 11 | oussouye
# Processing Record 24 of Set 11 | darovskoy
# Processing Record 25 of Set 11 | cravo norte
# Processing Record 26 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 27 of Set 11 | englehart
# Processing Record 28 of Set 11 | inongo
# Processing Record 29 of Set 11 | santa marta
# Processing Record 30 of Set 11 | palafrugell
# Processing Record 31 of Set 11 | carolina
# Processing Record 32 of Set 11 | repatriacion
# Processing Record 33 of Set 11 | shimoda
# Processing Record 34 of Set 11 | andenes
# Processing Record 35 of Set 11 | mananara
# Processing Record 36 of Set 11 | toamasina
# Processing Record 37 of Set 11 | nuuk
# Processing Record 38 of Set 11 | tingrela
# City not found. Skipping...
# Processing Record 39 of Set 11 | dali
# Processing Record 40 of Set 11 | sulangan
# Processing Record 41 of Set 11 | coihaique
# Processing Record 42 of Set 11 | tilichiki
# Processing Record 43 of Set 11 | buin
# Processing Record 44 of Set 11 | elliot lake
# Processing Record 45 of Set 11 | tuatapere
# Processing Record 46 of Set 11 | san andres
# Processing Record 47 of Set 11 | thunder bay
# Processing Record 48 of Set 11 | lasa
# Processing Record 49 of Set 11 | urtaaul
# City not found. Skipping...
# Processing Record 50 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 12 | fare
# Processing Record 2 of Set 12 | fukue
# Processing Record 3 of Set 12 | khash
# Processing Record 4 of Set 12 | brunico
# Processing Record 5 of Set 12 | langarud
# Processing Record 6 of Set 12 | kyshtovka
# Processing Record 7 of Set 12 | ostrovnoy
# Processing Record 8 of Set 12 | sola
# Processing Record 9 of Set 12 | prince albert
# Processing Record 10 of Set 12 | noumea
# Processing Record 11 of Set 12 | bestobe
# Processing Record 12 of Set 12 | haimen
# Processing Record 13 of Set 12 | marawi
# Processing Record 14 of Set 12 | beringovskiy
# Processing Record 15 of Set 12 | tessalit
# Processing Record 16 of Set 12 | haines junction
# Processing Record 17 of Set 12 | ambunti
# Processing Record 18 of Set 12 | avera
# Processing Record 19 of Set 12 | ouesso
# Processing Record 20 of Set 12 | husavik
# Processing Record 21 of Set 12 | bella union
# Processing Record 22 of Set 12 | presidencia roque saenz pena
# Processing Record 23 of Set 12 | starkville
# Processing Record 24 of Set 12 | mulege
# Processing Record 25 of Set 12 | mananjary
# Processing Record 26 of Set 12 | hami
# Processing Record 27 of Set 12 | sosua
# Processing Record 28 of Set 12 | kirkland lake
# Processing Record 29 of Set 12 | pimentel
# Processing Record 30 of Set 12 | merauke
# Processing Record 31 of Set 12 | kimparana
# Processing Record 32 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 33 of Set 12 | kieta
# Processing Record 34 of Set 12 | teahupoo
# Processing Record 35 of Set 12 | torquay
# Processing Record 36 of Set 12 | slobidka
# Processing Record 37 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 12 | beloha
# Processing Record 39 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 12 | muzhi
# Processing Record 41 of Set 12 | yaan
# Processing Record 42 of Set 12 | soyo
# Processing Record 43 of Set 12 | zhicheng
# Processing Record 44 of Set 12 | tondano
# Processing Record 45 of Set 12 | sumbe
# Processing Record 46 of Set 12 | adrar
# Processing Record 47 of Set 12 | altay
# Processing Record 48 of Set 12 | aklavik
# Processing Record 49 of Set 12 | aasiaat
# Processing Record 50 of Set 12 | jishui
# Processing Record 1 of Set 13 | sydney
# Processing Record 2 of Set 13 | gweta
# Processing Record 3 of Set 13 | porto seguro
# Processing Record 4 of Set 13 | ranau
# Processing Record 5 of Set 13 | villa carlos paz
# Processing Record 6 of Set 13 | rio tercero
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | iguape
# Processing Record 9 of Set 13 | bandarbeyla
# Processing Record 10 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 11 of Set 13 | caucaia
# Processing Record 12 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 13 | mtwara
# Processing Record 14 of Set 13 | port hedland
# Processing Record 15 of Set 13 | mwinilunga
# Processing Record 16 of Set 13 | san luis
# Processing Record 17 of Set 13 | shakiso
# Processing Record 18 of Set 13 | parana
# Processing Record 19 of Set 13 | sur
# Processing Record 20 of Set 13 | oliva
# Processing Record 21 of Set 13 | mareeba
# Processing Record 22 of Set 13 | hameenlinna
# Processing Record 23 of Set 13 | novyy svit
# Processing Record 24 of Set 13 | itupiranga
# Processing Record 25 of Set 13 | tadine
# Processing Record 26 of Set 13 | rio cuarto
# Processing Record 27 of Set 13 | boende
# Processing Record 28 of Set 13 | yorosso
# Processing Record 29 of Set 13 | nioro
# Processing Record 30 of Set 13 | qasigiannguit
# Processing Record 31 of Set 13 | sapele
# Processing Record 32 of Set 13 | tukrah
# Processing Record 33 of Set 13 | san juan
# Processing Record 34 of Set 13 | los negros
# Processing Record 35 of Set 13 | bucerias
# Processing Record 36 of Set 13 | bonavista
# Processing Record 37 of Set 13 | pimenteiras
# Processing Record 38 of Set 13 | kamaishi
# Processing Record 39 of Set 13 | mayo
# Processing Record 40 of Set 13 | anuppur
# Processing Record 41 of Set 13 | wageningen
# Processing Record 42 of Set 13 | ambanja
# Processing Record 43 of Set 13 | iracoubo
# Processing Record 44 of Set 13 | mangrol
# Processing Record 45 of Set 13 | nileshwar
# Processing Record 46 of Set 13 | west wendover
# Processing Record 47 of Set 13 | hirara
# Processing Record 48 of Set 13 | pulandian
# Processing Record 49 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 13 | tolaga bay
# Processing Record 1 of Set 14 | darnah
# Processing Record 2 of Set 14 | sao jose da coroa grande
# Processing Record 3 of Set 14 | gat
# Processing Record 4 of Set 14 | payo
# Processing Record 5 of Set 14 | blagoyevo
# Processing Record 6 of Set 14 | wanaka
# Processing Record 7 of Set 14 | boa vista
# Processing Record 8 of Set 14 | bathsheba
# Processing Record 9 of Set 14 | gornopravdinsk
# Processing Record 10 of Set 14 | yerbogachen
# Processing Record 11 of Set 14 | nebug
# Processing Record 12 of Set 14 | mglin
# Processing Record 13 of Set 14 | padang
# Processing Record 14 of Set 14 | durgapur
# Processing Record 15 of Set 14 | shahrud
# Processing Record 16 of Set 14 | tornio
# Processing Record 17 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 18 of Set 14 | alcudia
# Processing Record 19 of Set 14 | mushie
# Processing Record 20 of Set 14 | adwa
# Processing Record 21 of Set 14 | tabou
# Processing Record 22 of Set 14 | aksarka
# Processing Record 23 of Set 14 | alugan
# Processing Record 24 of Set 14 | sebu
# Processing Record 25 of Set 14 | torrington
# Processing Record 26 of Set 14 | diamantino
# Processing Record 27 of Set 14 | luganville
# Processing Record 28 of Set 14 | novyy urengoy
# Processing Record 29 of Set 14 | bauska
# Processing Record 30 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 31 of Set 14 | aldan
# Processing Record 32 of Set 14 | cianjur
# Processing Record 33 of Set 14 | vestmanna
# Processing Record 34 of Set 14 | hobyo
# Processing Record 35 of Set 14 | bull savanna
# Processing Record 36 of Set 14 | talcahuano
# Processing Record 37 of Set 14 | college
# Processing Record 38 of Set 14 | kupang
# Processing Record 39 of Set 14 | morro bay
# Processing Record 40 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 41 of Set 14 | kaka
# Processing Record 42 of Set 14 | rudsar
# Processing Record 43 of Set 14 | turka
# Processing Record 44 of Set 14 | nunkini
# Processing Record 45 of Set 14 | lang suan
# Processing Record 46 of Set 14 | taywarah
# Processing Record 47 of Set 14 | manavalakurichi
# Processing Record 48 of Set 14 | togur
# Processing Record 49 of Set 14 | porosozero
# Processing Record 50 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 1 of Set 15 | birao
# Processing Record 2 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 15 | camacha
# Processing Record 4 of Set 15 | ibra
# Processing Record 5 of Set 15 | idlib
# Processing Record 6 of Set 15 | moron
# Processing Record 7 of Set 15 | dwarka
# Processing Record 8 of Set 15 | goranboy
# Processing Record 9 of Set 15 | palana
# Processing Record 10 of Set 15 | beipiao
# Processing Record 11 of Set 15 | manzanillo
# Processing Record 12 of Set 15 | ust-tsilma
# Processing Record 13 of Set 15 | sheltozero
# Processing Record 14 of Set 15 | stornoway
# Processing Record 15 of Set 15 | anqing
# Processing Record 16 of Set 15 | great yarmouth
# Processing Record 17 of Set 15 | synya
# Processing Record 18 of Set 15 | isla mujeres
# Processing Record 19 of Set 15 | bajo baudo
# City not found. Skipping...
# Processing Record 20 of Set 15 | vaitape
# Processing Record 21 of Set 15 | poum
# Processing Record 22 of Set 15 | rawson
# Processing Record 23 of Set 15 | baft
# Processing Record 24 of Set 15 | ust-maya
# Processing Record 25 of Set 15 | itarema
# Processing Record 26 of Set 15 | along
# Processing Record 27 of Set 15 | xiashi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", ]]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     44.47        82         100
# 1    Poykovskiy      RU  61.2333   73.3333     70.09        68           0
# 2      Kirakira      SB -10.4544  161.9205     77.16        89          97
# 3  Ponta Do Sol      PT  32.6667  -17.1000     85.71        69          85
# 4  Kristinehamn      SE  59.3098   14.1081     67.98        66           7
# 5         Asosa      ET  10.0667   34.5333     66.90        93          74
# 6        Barrow      US  71.2906 -156.7887     44.62        87          90
# 7   Port Alfred      ZA -33.5906   26.8910     61.38        66          75
# 8  Punta Arenas      CL -53.1500  -70.9167     35.62        96         100
# 9      Hermanus      ZA -34.4187   19.2345     59.81        65           0
#
#    Wind Speed Current Description
# 0        6.69     overcast clouds
# 1        6.71           clear sky
# 2        9.33     overcast clouds
# 3        2.42     overcast clouds
# 4       20.98          light rain
# 5        3.71          light rain
# 6       21.85          light rain
# 7       18.68       broken clouds
# 8        1.25     overcast clouds
# 9       15.88           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
